# %%
import pandas as pd

# %% [markdown]
# # Consolidação de Conhecimentos em Pandas
#
# Ao longo das aulas anteriores, tivemos o primeiro contacto com a biblioteca **pandas**, explorando os seus principais conceitos e ferramentas para manipulação de dados em Python. Este notebook surge agora com um novo objetivo: **consolidar esse conhecimento**.
#
# Mais do que introduzir novos conteúdos de forma isolada, a proposta aqui é reforçar aquilo que já foi aprendido, aprofundar a compreensão dos conceitos fundamentais e esclarecer dúvidas que surgiram — especialmente aquelas identificadas em avaliações anteriores.
#
# A consolidação é uma etapa essencial no processo de aprendizagem. É neste momento que deixamos de apenas reconhecer conceitos para **os aplicar com segurança e autonomia**. Por isso, ao longo deste notebook, serão revisitados temas importantes como:
#
# - Estruturas fundamentais do pandas (Series e DataFrames)
# - Leitura e escrita de dados
# - Seleção e filtragem
# - Manipulação e transformação de dados
# - Tratamento de valores em falta
#
# Este trabalho também servirá como preparação para o próximo passo: **Data Wrangling** — o processo de limpeza, transformação e organização de dados brutos em formatos adequados para análise.
#
# A ideia é que, ao final desta revisão, estejam mais confiantes na utilização do pandas e mais preparados para lidar com problemas reais de dados.
#
# Vamos a isso !
#
#
# ---

# %% [markdown]
# ## Series vs DataFrame
#
# No **pandas**, existem duas estruturas de dados fundamentais: **Series** e **DataFrame**. Compreender bem a diferença entre estas duas estruturas é essencial, pois praticamente todas as operações que realizamos vão envolver uma delas.
#
# ### Series
#
# Uma **Series** é uma estrutura de dados **unidimensional**, ou seja, funciona como uma lista ou uma coluna de uma tabela.
#
# - Possui **um único eixo** (valores)
# - Cada elemento está associado a um **índice**
# - Pode armazenar qualquer tipo de dados (inteiros, strings, floats, etc.)

# %%
obj2 = pd.Series([4, 7,-5, 3], index=["d", "b", "a", "c"])
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
#selecionar uma linha passando o nome do indice
print(obj2["a"])
# Out:
# -5

# %%
#iloc funciona
print(obj2.iloc[2])
# Out:
# -5

# %%
#loc também
print(obj2.loc["c"])
# Out:
# 3

# %%
#filtros em serie de dados. Aqui nao precisa indicar a coluna. Só tem uma coluna
obj2[obj2 > 0]
# Out:
# d    4
# b    7
# c    3
# dtype: int64

# %%
#operacoes com todos os elementos da serie
print(obj2 * 2)
# Out:
# d     8
# b    14
# a   -10
# c     6
# dtype: int64

# %%
#quando iterage com a serie o que acontece
for i in obj2:
    print(i)

#quando iteragem com um dataframe o que acontecia??
# Out:
# 4
# 7
# -5
# 3

# %%
#operador in aqui testa um index e nao um valor
"b" in obj2
# Out:
# True

# %%
#criando uma serie a partir de um dicionário
sdata = {"Ohio": 35000, "Texas": 71000, "Oregon": 16000, "Utah": 5000}
obj3 = pd.Series(sdata)
obj3
#portanto nao precisa criar como fizemos antes, a partir de duas listas. Awui ele ja identifica as chaves do dicionário como indices e os valores como os dados da serie
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
#da pra voltar de uma serie para um dicionário
a = obj3.to_dict()
print(a)
# Out:
# {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}

# %%
sdata = {"Ohio": 35000, "Texas": 71000, "Oregon": 16000, "Utah": 5000}
#se passar uma key que nao estiver no dicionário ele coloca NaN
states = ["California", "Ohio", "Oregon", "Texas"]
obj4 = pd.Series(sdata, index=states)
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
#ja aprendemos a localizar NaN
pd.isnull(obj4)

# #ou
# pd.notnull(obj4)
# #ou
# pd.isna(obj4)
# #ou
# pd.notna(obj4)
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
#da pra usar operador "+" em duas series
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
obj3 + obj4
# Out:
# California         NaN
# Ohio           70000.0
# Oregon         32000.0
# Texas         142000.0
# Utah               NaN
# dtype: float64

# %%
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
obj4.name = "population"
obj4.index.name = "state"
obj4
# Out:
# state
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# Name: population, dtype: float64

# %%
#posso editar indices a qualquer momento
obj = pd.Series([4, 7,-5, 3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj.index = ["Bob", "Steve", "Jeff", "Ryan"]
obj
# Out:
# Bob      4
# Steve    7
# Jeff    -5
# Ryan     3
# dtype: int64

# %% [markdown]
# ### DataFrame
#
# Um **DataFrame** é uma estrutura **bidimensional**, ou seja, uma tabela com linhas e colunas.
#
# - Possui **dois eixos** (linhas e colunas)
# - Cada coluna é, na prática, uma **Series**
# - Permite armazenar diferentes tipos de dados em colunas diferentes

# %%
data = {"state": ["Ohio", "Ohio", "Ohio", "Nevada", "Nevada", "Nevada"],
        "year": [2000, 2001, 2002, 2001, 2002, 2003],
        "pop": [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}

frame = pd.DataFrame(data)
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
#head e tail
frame.head(3) #padrao é 5
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
frame.tail(3) #padrao é 5
# Out:
#     state  year  pop
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
pd.DataFrame(data, columns=["year", "state", "pop"]) #isso cria um dataframe mas precisa ser igualado a uma variavel para guardar
#o mesmo que
# frame[["year", "state", "pop"]] #portanto isso nao muda o original, apenas mostra a ordem diferente
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Nevada  3.2

# %%
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
frame2 = pd.DataFrame(data, columns=["year", "state", "pop", "debt"]) #passando uma coluna que nao existe ele cria a coluna mas com NaN
frame2
# Out:
#    year   state  pop debt
# 0  2000    Ohio  1.5  NaN
# 1  2001    Ohio  1.7  NaN
# 2  2002    Ohio  3.6  NaN
# 3  2001  Nevada  2.4  NaN
# 4  2002  Nevada  2.9  NaN
# 5  2003  Nevada  3.2  NaN

# %%
#quando iteragem com um dataframe
for i in frame2:
    print(i)

print("-"*20)
#na serie retornava os valores das linhas
for i in obj2:
    print(i)
# Out:
# year
# state
# pop
# debt
# --------------------
# 4
# 7
# -5
# 3

# %%
#voltando para o dataframe
frame2
# Out:
#    year   state  pop debt
# 0  2000    Ohio  1.5  NaN
# 1  2001    Ohio  1.7  NaN
# 2  2002    Ohio  3.6  NaN
# 3  2001  Nevada  2.4  NaN
# 4  2002  Nevada  2.9  NaN
# 5  2003  Nevada  3.2  NaN

# %%
#obter os dados de uma coluna
frame2["state"]
# Out:
# 0      Ohio
# 1      Ohio
# 2      Ohio
# 3    Nevada
# 4    Nevada
# 5    Nevada
# Name: state, dtype: str

# %%
a = frame2["state"]
print(type(a))

#se quiser em lista tem que ser
b = frame2["state"].tolist()
print(type(b))
# Out:
# <class 'pandas.Series'>
# <class 'list'>

# %%
#jeito mais "escondido"
frame2.state
# Out:
# 0      Ohio
# 1      Ohio
# 2      Ohio
# 3    Nevada
# 4    Nevada
# 5    Nevada
# Name: state, dtype: str

# %% [markdown]
# `frame2[column]` works for any column name, but frame2.column works only when the column name is a valid Python variable name and does not conflict with any of the method names in DataFrame.
#
# For example, if a column’s name contains whitespace or symbols other than underscores, it cannot be accessed with the dot attribute method.

# %%
data = {"state": ["Ohio", "Ohio", "Ohio", "Nevada", "Nevada", "Nevada"],
        "year of": [2000, 2001, 2002, 2001, 2002, 2003],
        "pop": [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
frame3 = pd.DataFrame(data, columns=["year of", "state", "pop", "debt"]) #passando uma coluna que nao existe ele cria a coluna mas com NaN
frame3["year of"]
# Out:
# 0    2000
# 1    2001
# 2    2002
# 3    2001
# 4    2002
# 5    2003
# Name: year of, dtype: int64

# %%
frame3.year of
# Out:
#   Cell In[59], line 1
#     frame3.year of
#                 ^
# SyntaxError: invalid syntax

# %%
#voltando a frame2
frame2
# Out:
#    year   state  pop debt
# 0  2000    Ohio  1.5  NaN
# 1  2001    Ohio  1.7  NaN
# 2  2002    Ohio  3.6  NaN
# 3  2001  Nevada  2.4  NaN
# 4  2002  Nevada  2.9  NaN
# 5  2003  Nevada  3.2  NaN

# %%
frame2["debt"] = 16.5
frame2
# Out:
#    year   state  pop  debt
# 0  2000    Ohio  1.5  16.5
# 1  2001    Ohio  1.7  16.5
# 2  2002    Ohio  3.6  16.5
# 3  2001  Nevada  2.4  16.5
# 4  2002  Nevada  2.9  16.5
# 5  2003  Nevada  3.2  16.5

# %%
#pode ser uma lista
lista_debt = [16.5, 5, 17.5, 100, 18.5, 19.5]
frame2["debt"] = lista_debt
frame2
# Out:
#    year   state  pop   debt
# 0  2000    Ohio  1.5   16.5
# 1  2001    Ohio  1.7    5.0
# 2  2002    Ohio  3.6   17.5
# 3  2001  Nevada  2.4  100.0
# 4  2002  Nevada  2.9   18.5
# 5  2003  Nevada  3.2   19.5

# %%
# um indice é importante pq quando importo dados posso aproveitar e colocar dados em lugares especificos
val = pd.Series([-1.2, -1.5, -1.7], index=[0, 2, 3]) #aqui usando uma serie com index em expecificos
frame2
# Out:
#    year   state  pop   debt  val
# 0  2000    Ohio  1.5   16.5 -1.2
# 1  2001    Ohio  1.7    5.0  NaN
# 2  2002    Ohio  3.6   17.5 -1.5
# 3  2001  Nevada  2.4  100.0 -1.7
# 4  2002  Nevada  2.9   18.5  NaN
# 5  2003  Nevada  3.2   19.5  NaN

# %%
frame2["eastern"] = frame2["state"] == "Ohio"
frame2
# Out:
#    year   state  pop   debt  val  eastern
# 0  2000    Ohio  1.5   16.5 -1.2     True
# 1  2001    Ohio  1.7    5.0  NaN     True
# 2  2002    Ohio  3.6   17.5 -1.5     True
# 3  2001  Nevada  2.4  100.0 -1.7    False
# 4  2002  Nevada  2.9   18.5  NaN    False
# 5  2003  Nevada  3.2   19.5  NaN    False

# %%
frame2.eastern2 = frame2["state"] == "Ohio"
frame2
# Out:
# /var/folders/wv/lsjsk14j2hs2j2fw_6d4mtpm0000gn/T/ipykernel_8950/2131565667.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   frame2.eastern2 = frame2["state"] == "Ohio"
#    year   state  pop   debt  val  eastern
# 0  2000    Ohio  1.5   16.5 -1.2     True
# 1  2001    Ohio  1.7    5.0  NaN     True
# 2  2002    Ohio  3.6   17.5 -1.5     True
# 3  2001  Nevada  2.4  100.0 -1.7    False
# 4  2002  Nevada  2.9   18.5  NaN    False
# 5  2003  Nevada  3.2   19.5  NaN    False

# %%
#removendo uma coluna
del frame2["eastern"]
frame2
# Out:
#    year   state  pop   debt  val
# 0  2000    Ohio  1.5   16.5 -1.2
# 1  2001    Ohio  1.7    5.0  NaN
# 2  2002    Ohio  3.6   17.5 -1.5
# 3  2001  Nevada  2.4  100.0 -1.7
# 4  2002  Nevada  2.9   18.5  NaN
# 5  2003  Nevada  3.2   19.5  NaN

# %%
#transpondo o dataframe
populations = {"Ohio": {2000: 1.5, 2001: 1.7, 2002: 3.6},"Nevada": {2001: 2.4, 2002: 2.9}}
frame3 = pd.DataFrame(populations)
frame3
# Out:
#       Ohio  Nevada
# 2000   1.5     NaN
# 2001   1.7     2.4
# 2002   3.6     2.9

# %%
frame3.T
# Out:
#         2000  2001  2002
# Ohio     1.5   1.7   3.6
# Nevada   NaN   2.4   2.9

# %%
pd.DataFrame(populations, index=[2001, 2002, 2003])
# Out:
#       Ohio  Nevada
# 2001   1.7     2.4
# 2002   3.6     2.9
# 2003   NaN     NaN

# %% [markdown]
# ![Possible data inputs to the DataFrame constructor](table1.png)

# %% [markdown]
# ## O Index no Pandas
#
# O **Index** é um dos elementos fundamentais no pandas e está presente tanto em **Series** quanto em **DataFrames**. Ele funciona como um conjunto de **rótulos (labels)** que identificam cada linha (e também cada coluna, no caso de DataFrames).
#
# ### O que é o Index?
#
# Podemos pensar no **Index** como o "nome" ou "identificador" de cada linha.
#
# - É **imutável** (não pode ser alterado diretamente)
# - Garante o **alinhamento dos dados** em operações
# - Pode conter valores únicos ou repetidos (embora o ideal seja serem únicos)
#
# ---

# %%
obj = pd.Series([1,2,3], index=["a", "b", "c"])
obj
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
index_serie = obj.index
print(index_serie)
# Out:
# Index(['a', 'b', 'c'], dtype='str')

# %%
index_serie[1]
# Out:
# 'b'

# %%
index_serie[1] = "d" #isso da erro pq o index é imutável
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 index_serie[1] = "d" #isso da erro pq o index é imutável
#
# File ~/Documents/03_teaching/AED/EDA/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:5382, in Index.__setitem__(self, key, value)
#    5380 @final
#    5381 def __setitem__(self, key, value) -> None:
# -> 5382     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %%
frame3
# Out:
#       Ohio  Nevada
# 2000   1.5     NaN
# 2001   1.7     2.4
# 2002   3.6     2.9

# %%
index_columns = frame3.columns
print(index_columns)
# Out:
# Index(['Ohio', 'Nevada'], dtype='str')

# %%
index_columns[1]
# Out:
# 'Nevada'

# %%
index_columns[1] = "estado" #isso da erro pq o index é imutável
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 index_columns[1] = "estado" #isso da erro pq o index é imutável
#
# File ~/Documents/03_teaching/AED/EDA/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:5382, in Index.__setitem__(self, key, value)
#    5380 @final
#    5381 def __setitem__(self, key, value) -> None:
# -> 5382     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %% [markdown]
# ## Funcionalidades Essenciais no Pandas
#
# Depois de consolidarmos as estruturas fundamentais do pandas — como **Series**, **DataFrames** e **Index** — o próximo passo é explorar as **operações essenciais** que nos permitem trabalhar com os dados de forma prática.
#
# No dia a dia, utilizar pandas não é apenas armazenar dados, mas sim **transformá-los, reorganizá-los e extrair informação relevante**. É aqui que entram as funcionalidades centrais da biblioteca, que tornam possível:
#
# - Ajustar e reorganizar estruturas de dados
# - Remover ou modificar informação
# - Selecionar subconjuntos de dados
# - Realizar operações entre diferentes conjuntos de dados
# - Aplicar funções de forma eficiente
#
# Estas operações formam a base de praticamente todo o trabalho com dados em pandas. Em vez de abordar cada conceito apenas de forma teórica, vamos explorá-los diretamente através de **exemplos práticos em código**, de modo a reforçar a intuição e a capacidade de aplicação.
#
# O objetivo é que, ao trabalhar com estes exemplos, consigam reconhecer padrões e desenvolver confiança para resolver problemas reais de manipulação de dados.

# %%
obj = pd.Series([4.5, 7.2,-5.3, 3.6], index=["d", "b", "a", "c"])
obj
# Out:
# d    4.5
# b    7.2
# a   -5.3
# c    3.6
# dtype: float64

# %%
obj2 = obj.reindex(["a", "b", "c", "d", "e"])
obj2
#portanto ele mantei os valores da serie anterior e para os valores que nao existe ele coloca NaN
# Out:
# a   -5.3
# b    7.2
# c    3.6
# d    4.5
# e    NaN
# dtype: float64

# %%
obj3 = pd.Series(["blue", "purple", "yellow"], index=[0, 2, 4])
obj3
# Out:
# 0      blue
# 2    purple
# 4    yellow
# dtype: str

# %%
obj3.reindex(range(6), method="ffill") #ffill é forward fill, ou seja, preenche os valores NaN com o valor anterior
# Out:
# 0      blue
# 1      blue
# 2    purple
# 3    purple
# 4    yellow
# 5    yellow
# dtype: str

# %%
#dropping entries
obj = pd.Series([2,3,4,5,6], index=["a", "b", "c", "d", "e"])
obj
# Out:
# a    2
# b    3
# c    4
# d    5
# e    6
# dtype: int64

# %%
new_obj = obj.drop("c")
obj
# Out:
# a    2
# b    3
# c    4
# d    5
# e    6
# dtype: int64

# %%
new_obj
# Out:
# a    2
# b    3
# d    5
# e    6
# dtype: int64

# %%
obj.drop(["d", "c"])
# Out:
# a    2
# b    3
# e    6
# dtype: int64

# %%
import numpy as np
data = pd.DataFrame(np.arange(16).reshape((4, 4)), index=["Ohio", "Colorado", "Utah", "New York"], columns=["one", "two", "three", "four"])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.drop(index=["Colorado", "Ohio"])
# Out:
#           one  two  three  four
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.drop("two", axis=1)
# Out:
#           one  three  four
# Ohio        0      2     3
# Colorado    4      6     7
# Utah        8     10    11
# New York   12     14    15

# %%
data.drop("two", axis="columns")
# Out:
#           one  three  four
# Ohio        0      2     3
# Colorado    4      6     7
# Utah        8     10    11
# New York   12     14    15

# %%
data.drop("Ohio", axis=0)
# Out:
#           one  two  three  four
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.drop("Ohio", axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 data.drop("Ohio", axis=1)
#
# File ~/Documents/03_teaching/AED/EDA/.venv/lib/python3.13/site-packages/pandas/core/frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
#    6289         labels=labels,
#    6290         axis=axis,
#    6291         index=index,
#    6292         columns=columns,
#    6293         level=level,
#    6294         inplace=inplace,
#    6295         errors=errors,
#    6296     )
#
# File ~/Documents/03_teaching/AED/EDA/.venv/lib/python3.13/site-packages/pandas/core/generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4642 for axis, labels in axes.items():
#    4643     if labels is not None:
# -> 4644         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4646 if inplace:
#    4647     self._update_inplace(obj)
#
# File ~/Documents/03_teaching/AED/EDA/.venv/lib/python3.13/site-packages/pandas/core/generic.py:4686, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4684         new_axis = axis.drop(labels, level=level, errors=errors)
#    4685     else:
# -> 4686         new_axis = axis.drop(labels, errors=errors)
#    4687     indexer = axis.get_indexer(new_axis)
#    4689 # Case for non-unique axis
#    4690 else:
#
# File ~/Documents/03_teaching/AED/EDA/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:7268, in Index.drop(self, labels, errors)
#    7266 if mask.any():
#    7267     if errors != "ignore":
# -> 7268         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7269     indexer = indexer[~mask]
#    7270 return self.delete(indexer)
#
# KeyError: "['Ohio'] not found in axis"

# %%
obj = pd.Series(np.arange(4.), index=["a", "b", "c", "d"])
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# dtype: float64

# %%
obj["b"]
# Out:
# np.float64(1.0)

# %%
obj[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/03_teaching/AED/EDA/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:578, in pandas._libs.index.StringObjectEngine._check_type()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 obj[1]
#
# File ~/Documents/03_teaching/AED/EDA/.venv/lib/python3.13/site-packages/pandas/core/series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# --> 959     return self._get_value(key)
#     961 # Convert generator to list before going through hashable part
#     962 # (We will iterate through the generator there to check for slices)
#     963 if is_iterator(key):
#
# File ~/Documents/03_teaching/AED/EDA/.venv/lib/python3.13/site-packages/pandas/core/series.py:1046, in Series._get_value(self, label, takeable)
#    1043     return self._values[label]
#    1045 # Similar to Index.get_value, but we do not fall back to positional
# -> 1046 loc = self.index.get_loc(label)
#    1048 if is_integer(loc):
#    1049     return self._values[loc]
#
# File ~/Documents/03_teaching/AED/EDA/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 1

# %%
obj[1:]
# Out:
# b    1.0
# c    2.0
# d    3.0
# dtype: float64

# %%
obj[["b","c"]]
# Out:
# b    1.0
# c    2.0
# dtype: float64

# %%
obj
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# dtype: float64

# %%
obj["b":"c"]
# Out:
# b    1.0
# c    2.0
# dtype: float64

# %%
obj["a":"c"]
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %%
obj["b":]
# Out:
# b    1.0
# c    2.0
# d    3.0
# dtype: float64

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),index=["Ohio", "Colorado", "Utah", "New York"],columns=["one", "two", "three", "four"])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data[data["three"] > 5]
# Out:
#           one  two  three  four
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
#decompondo as componentes do filtro
data["three"] > 5
# Out:
# Ohio        False
# Colorado     True
# Utah         True
# New York     True
# Name: three, dtype: bool

# %%
#ou
lista_bool = [False, True, True, True]

data[lista_bool]
# Out:
#           one  two  three  four
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data[data["three"] > 5]
# Out:
#           one  two  three  four
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
#da pra transformar o dataframe em um dataframe booleano
data > 5
# Out:
#             one    two  three   four
# Ohio      False  False  False  False
# Colorado  False  False   True   True
# Utah       True   True   True   True
# New York   True   True   True   True

# %% [markdown]
# ![Indexing options with DataFrame](table2.png)

# %%
#da pra acessar um valor usando endereço negativo?
ser = pd.Series(np.arange(3.))
ser
# Out:
# 0    0.0
# 1    1.0
# 2    2.0
# dtype: float64

# %%
ser[0]
# Out:
# np.float64(0.0)

# %%
ser[-1] #isso da erro, nao funciona com endereço negativo
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/03_teaching/AED/EDA/.venv/lib/python3.13/site-packages/pandas/core/indexes/range.py:521, in RangeIndex.get_loc(self, key)
#     520 try:
# --> 521     return self._range.index(new_key)
#     522 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 ser[-1] #isso da erro, nao funciona com endereço negativo
#
# File ~/Documents/03_teaching/AED/EDA/.venv/lib/python3.13/site-packages/pandas/core/series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# --> 959     return self._get_value(key)
#     961 # Convert generator to list before going through hashable part
#     962 # (We will iterate through the generator there to check for slices)
#     963 if is_iterator(key):
#
# File ~/Documents/03_teaching/AED/EDA/.venv/lib/python3.13/site-packages/pandas/core/series.py:1046, in Series._get_value(self, label, takeable)
#    1043     return self._values[label]
#    1045 # Similar to Index.get_value, but we do not fall back to positional
# -> 1046 loc = self.index.get_loc(label)
#    1048 if is_integer(loc):
#    1049     return self._values[loc]
#
# File ~/Documents/03_teaching/AED/EDA/.venv/lib/python3.13/site-packages/pandas/core/indexes/range.py:523, in RangeIndex.get_loc(self, key)
#     521         return self._range.index(new_key)
#     522     except ValueError as err:
# --> 523         raise KeyError(key) from err
#     524 if isinstance(key, Hashable):
#     525     raise KeyError(key)
#
# KeyError: -1

# %%
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.loc[:, "one"] = 1
data
# Out:
#           one  two  three  four
# Ohio        1    1      2     3
# Colorado    1    5      6     7
# Utah        1    9     10    11
# New York    1   13     14    15

# %%
#ou
data["one"] = 5
data
# Out:
#           one  two  three  four
# Ohio        5    1      2     3
# Colorado    5    5      6     7
# Utah        5    9     10    11
# New York    5   13     14    15

# %%
s1 = pd.Series([7.3,-2.5, 3.4, 1.5], index=["a", "c", "d", "e"])
s2 = pd.Series([-2.1, 3.6,-1.5, 4, 3.1],index=["a", "c", "e", "f", "g"])

# %%
s1 + s2 #só soma os valores que tem o mesmo indice, os outros ficam com NaN
# Out:
# a    5.2
# c    1.1
# d    NaN
# e    0.0
# f    NaN
# g    NaN
# dtype: float64

# %%
df1 = pd.DataFrame(np.arange(9.).reshape((3, 3)), columns=list("bcd"),index=["Ohio", "Texas", "Colorado"])
df2 = pd.DataFrame(np.arange(12.).reshape((4, 3)), columns=list("bde"),index=["Utah", "Ohio", "Texas", "Oregon"])

# %%
df1
# Out:
#             b    c    d
# Ohio      0.0  1.0  2.0
# Texas     3.0  4.0  5.0
# Colorado  6.0  7.0  8.0

# %%
df2
# Out:
#           b     d     e
# Utah    0.0   1.0   2.0
# Ohio    3.0   4.0   5.0
# Texas   6.0   7.0   8.0
# Oregon  9.0  10.0  11.0

# %%
df1 + df2 #soma os valores que tem o mesmo indice e mesma coluna, os outros ficam com NaN
# Out:
#             b   c     d   e
# Colorado  NaN NaN   NaN NaN
# Ohio      3.0 NaN   6.0 NaN
# Oregon    NaN NaN   NaN NaN
# Texas     9.0 NaN  12.0 NaN
# Utah      NaN NaN   NaN NaN

# %%
#criar dataframe a partir de uma lista de discionários
data = [{"a": i, "b": 2 * i} for i in range(3)]
pd.DataFrame(data)
#orientado a linhas
# Out:
#    a  b
# 0  0  0
# 1  1  2
# 2  2  4

# %%
#criar um dataframe a partir de um dicionário com listas
data = {
    "name":["a", "b", "c"],
    "age":[20, 30, 40],
    "city":["NY", "LA", "Chicago"]
}
pd.DataFrame(data)
#orientado a colunas
# Out:
#   name  age     city
# 0    a   20       NY
# 1    b   30       LA
# 2    c   40  Chicago

# %%
df3 = df1 + df2
df3
# Out:
#             b   c     d   e
# Colorado  NaN NaN   NaN NaN
# Ohio      3.0 NaN   6.0 NaN
# Oregon    NaN NaN   NaN NaN
# Texas     9.0 NaN  12.0 NaN
# Utah      NaN NaN   NaN NaN

# %%
df3.fillna(0) #preenche os valores NaN com 0
# Out:
#             b    c     d     e
# Colorado  6.0  7.0   8.0   0.0
# Ohio      3.0  1.0   6.0   5.0
# Oregon    9.0  0.0  10.0  11.0
# Texas     9.0  4.0  12.0   8.0
# Utah      0.0  0.0   1.0   2.0

# %%
1/df3 #isso é o mesmo que df3.rdiv(1), ou seja, divide 1 por cada elemento do dataframe, e os NaN continuam NaN
# Out:
#                  b         c         d         e
# Colorado  0.166667  0.142857  0.125000       NaN
# Ohio      0.333333  1.000000  0.166667  0.200000
# Oregon    0.111111       NaN  0.100000  0.090909
# Texas     0.111111  0.250000  0.083333  0.125000
# Utah           inf       NaN  1.000000  0.500000

# %%
frame = pd.DataFrame(np.arange(12.).reshape((4, 3)),columns=list("bde"),index=["Utah", "Ohio", "Texas", "Oregon"])
frame
# Out:
#           b     d     e
# Utah    0.0   1.0   2.0
# Ohio    3.0   4.0   5.0
# Texas   6.0   7.0   8.0
# Oregon  9.0  10.0  11.0

# %%
series = frame.iloc[0]
series
# Out:
# b    0.0
# d    1.0
# e    2.0
# Name: Utah, dtype: float64

# %%
frame - series
#matches the index of the Series to the columns of the DataFrame and performs the subtraction
# Out:
#           b    d    e
# Utah    0.0  0.0  0.0
# Ohio    3.0  3.0  3.0
# Texas   6.0  6.0  6.0
# Oregon  9.0  9.0  9.0

# %%
#aplicando funcoes
frame = pd.DataFrame(np.random.standard_normal((4, 3)),columns=list("bde"),index=["Utah", "Ohio", "Texas", "Oregon"])
frame
# Out:
#                b         d         e
# Utah    0.079134 -0.214434  1.190364
# Ohio   -0.122965  1.435553 -0.657558
# Texas  -0.309042 -1.031761  0.875179
# Oregon -0.190603 -1.445766 -0.428386

# %%
np.abs(frame)
#usando funcoes diretas do numpy no dataframe, ele aplica a função a cada elemento do dataframe
# Out:
#                b         d         e
# Utah    0.079134  0.214434  1.190364
# Ohio    0.122965  1.435553  0.657558
# Texas   0.309042  1.031761  0.875179
# Oregon  0.190603  1.445766  0.428386

# %%
def f1(x):
    return x.max() - x.min()

frame.apply(f1) #aplica a função f1 a cada coluna do dataframe, ou seja, calcula a diferença entre o valor máximo e mínimo de cada coluna
# Out:
# b    0.388176
# d    2.881319
# e    1.847923
# dtype: float64

# %%
frame.apply(f1, axis="columns") #aplica a função f1 a cada linha do dataframe, ou seja, calcula a diferença entre o valor máximo e mínimo de cada linha
# Out:
# Utah      1.404798
# Ohio      2.093112
# Texas     1.906941
# Oregon    1.255163
# dtype: float64

# %%
def f2(x):
    return pd.Series([x.min(), x.max()], index=["min", "max"])

a = frame.apply(f2) #aplica a função f2 a cada coluna do dataframe, ou seja, calcula o valor mínimo e máximo de cada coluna e retorna uma série com esses valores
a
# Out:
#             b         d         e
# min -0.309042 -1.445766 -0.657558
# max  0.079134  1.435553  1.190364

# %%
type(a)
# Out:
# pandas.DataFrame

# %%
frame
# Out:
#                b         d         e
# Utah    0.079134 -0.214434  1.190364
# Ohio   -0.122965  1.435553 -0.657558
# Texas  -0.309042 -1.031761  0.875179
# Oregon -0.190603 -1.445766 -0.428386

# %%
frame["e"]
# Out:
# Utah      1.190364
# Ohio     -0.657558
# Texas     0.875179
# Oregon   -0.428386
# Name: e, dtype: float64

# %%
def my_format(x):
    return f"{x:.2f}"

frame.map(my_format)
# Out:
#             b      d      e
# Utah     0.08  -0.21   1.19
# Ohio    -0.12   1.44  -0.66
# Texas   -0.31  -1.03   0.88
# Oregon  -0.19  -1.45  -0.43

# %%
obj = pd.Series(np.arange(4), index=["d", "a", "b", "c"])
obj
# Out:
# d    0
# a    1
# b    2
# c    3
# dtype: int64

# %%
obj.sort_index()
# Out:
# a    1
# b    2
# c    3
# d    0
# dtype: int64

# %%
frame = pd.DataFrame(np.arange(8).reshape((2, 4)),
                     index=["three", "one"],
                     columns=["d", "a", "b", "c"])
frame
# Out:
#        d  a  b  c
# three  0  1  2  3
# one    4  5  6  7

# %%
frame.sort_index()
# Out:
#        d  a  b  c
# one    4  5  6  7
# three  0  1  2  3

# %%
frame
# Out:
#        d  a  b  c
# three  0  1  2  3
# one    4  5  6  7

# %%
frame.sort_index(axis="columns", ascending=True)
# Out:
#        a  b  c  d
# three  1  2  3  0
# one    5  6  7  4

# %%
frame.sort_values(by="a",ascending=False)
# Out:
#        d  a  b  c
# one    4  5  6  7
# three  0  1  2  3

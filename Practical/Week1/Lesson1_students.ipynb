# %% [markdown]
# ## 1. Primeiros passos (titanic)

# %% [markdown]
# Nesessário instalar bilbiotecas. Pode ser feito por aqui usando "!pip" ou usando terminal. Abaixo como instalar pandas.

# %%
# !pip install pandas

# %% [markdown]
# Uma vez instalada a biblioteca, é necessário importá-la para o ambiente de trabalho. O nome da biblioteca é "pandas" e a forma mais comum de a importar é usando o alias "pd". O alias é uma forma abreviada de se referir à biblioteca, facilitando a escrita do código.

# %%
import pandas as pd

# %% [markdown]
# ## 2. Importando dados

# %% [markdown]
# Inicialmente, vamos importar um dataset conhecido, o "titanic". Este dataset contém informações sobre os passageiros do navio Titanic, incluindo se eles sobreviveram ou não, sua classe de cabine, idade, sexo, entre outros dados.

# %%
#dataset source
path = "../../00_Datasets/titanic.csv"

#read dataframe
ds = pd.read_csv(path)

#show first 10 rows
ds.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
#show last 10 rows
ds.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# Descreva o que é cada linha e cada coluna. Faça um report sobre o seu entedimento.

# %% [markdown]
# Após analise do dataset acima quais incompatibilidades ou problemas de qualidade de dados voce identificou? Quais colunas tem valores faltantes? Quais colunas tem valores inconsistentes? Quais colunas tem valores duplicados? Quais colunas tem valores fora do intervalo esperado?

# %% [markdown]
# Uma maneira inteligente de fazer isso é talvez fazer uma coluna sumária que analise cada coluna e sua completude, consistência, duplicidade e validade. Portanto crie uma tabela sumária sobre com as colunas descritas abaixo:

# %%
#nome da coluna
#tipo de dados
#quantidade de valores únicos
#quantidade de valores faltantes
#quantidade de valores duplicados
#quantidade de dados inteiros
#quantidade de dados float
#quantidade de dados string
#quantidade de dados booleanos
#quantidade de dados nulos

# %% [markdown]
# Com base na analise da tabela acima quais questoes pode levantar sobre a integridade dos dados?

# %% [markdown]
# Com o seu conhecimento da historia do Titanic, quais hipoteses emergem a partir da sua exploracao dos dados? Quais perguntas voce gostaria de responder? Quais hipoteses voce gostaria de testar?

# %% [markdown]
# Se estiver sem ideias, tente responder as seguintes perguntas:
# - Qual era a proporção de sobreviventes em relação ao total de passageiros?
# - Qual era a proporção de sobreviventes por classe de cabine?
# - Qual era a proporção de sobreviventes por sexo?
# - Qual era a proporção de sobreviventes por faixa etária? `['0-12', '13-18', '19-35', '36-60', '60+']`
# - Qual era a proporção de sobreviventes por número de irmãos/cônjuges a bordo?
# - Qual era a proporção de sobreviventes por número de pais/filhos a bordo?
